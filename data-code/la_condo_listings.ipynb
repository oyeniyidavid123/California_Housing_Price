# %%
import requests

url = "https://realtor.p.rapidapi.com/properties/v2/list-for-sale"

querystring = {"sort":"relevance","prop_type":"condo","city":"Los Angeles","limit":"5000","offset":"0","state_code":"CA"}

headers = {
    'x-rapidapi-host': "realtor.p.rapidapi.com",
    'x-rapidapi-key': "ccd80db736mshcfc9234f86f9d33p12faf8jsn0eb2e033ed0c"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response_json=response.json()

print(response_json.keys())
# Out:
# dict_keys(['meta', 'properties'])

# %%
properties = response_json['properties']

# %%
import pandas as pd
CITY_NAME_DF = pd.DataFrame(properties)

# %%
la_listings = CITY_NAME_DF[['property_id', 'prop_type', 'address', 'price', 'baths_half', 'baths_full', 'beds', 'building_size']]
la_listings["baths_half"] = la_listings["baths_half"].fillna(0)
la_listings
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      property_id prop_type  ... beds                    building_size
# 0    M1871614480     condo  ...    2  {'size': 1102, 'units': 'sqft'}
# 1    M1521023494     condo  ...    2  {'size': 1244, 'units': 'sqft'}
# 2    M2286048569     condo  ...    3  {'size': 2628, 'units': 'sqft'}
# 3    M9715181242     condo  ...    4  {'size': 1918, 'units': 'sqft'}
# 4    M9295211483     condo  ...    3  {'size': 1786, 'units': 'sqft'}
# ..           ...       ...  ...  ...                              ...
# 195  M2340989511     condo  ...    2  {'size': 1916, 'units': 'sqft'}
# ...

# %%
from pandas.io.json import json_normalize
la_address = json_normalize(la_listings['address'])
la_address
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                   city  ... is_approximate
# 0          Los Angeles  ...            NaN
# 1              Burbank  ...            NaN
# 2          Playa Vista  ...            NaN
# 3             Winnetka  ...            NaN
# 4             Winnetka  ...            NaN
# ..                 ...  ...            ...
# 195  Pacific Palisades  ...            NaN
# 196        Los Angeles  ...            NaN
# 197        Los Angeles  ...            NaN
# 198             Sylmar  ...            NaN
# 199     Valley Village  ...            NaN
#
# [200 rows x 12 columns]

# %%
la_df = pd.concat([la_listings,la_address],axis=1)
la_df.dropna(subset=['building_size'], inplace=True)
la_df
# Out:
#      property_id prop_type  ...            time_zone  is_approximate
# 0    M1871614480     condo  ...                  NaN             NaN
# 1    M1521023494     condo  ...                  NaN             NaN
# 2    M2286048569     condo  ...  America/Los_Angeles             NaN
# 3    M9715181242     condo  ...                  NaN             NaN
# 4    M9295211483     condo  ...                  NaN             NaN
# ..           ...       ...  ...                  ...             ...
# 195  M2340989511     condo  ...                  NaN             NaN
# 196  M1573946266     condo  ...                  NaN             NaN
# 197  M2856613351     condo  ...                  NaN             NaN
# 198  M1728220056     condo  ...                  NaN             NaN
# 199  M2576741751     condo  ...                  NaN             NaN
#
# [200 rows x 20 columns]

# %%
building_size = json_normalize(la_df['building_size'])
building_size
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#      size units
# 0    1102  sqft
# 1    1244  sqft
# 2    2628  sqft
# 3    1918  sqft
# 4    1786  sqft
# ..    ...   ...
# 195  1916  sqft
# 196   650  sqft
# 197  1629  sqft
# 198  1616  sqft
# 199  1155  sqft
#
# [200 rows x 2 columns]

# %%
la_condo_df = pd.concat([la_listings, la_address, building_size],axis=1)
la_condo_df = pd.DataFrame(la_condo_df)
# Out:
#      property_id prop_type    price  ...  state_code       county  building_size
# 0    M1871614480     condo   475000  ...          CA  Los Angeles           1102
# 1    M1521023494     condo   525000  ...          CA  Los Angeles           1244
# 2    M2286048569     condo  1748000  ...          CA  Los Angeles           2628
# 3    M9715181242     condo   663990  ...          CA  Los Angeles           1918
# 4    M9295211483     condo   624990  ...          CA  Los Angeles           1786
# ..           ...       ...      ...  ...         ...          ...            ...
# 195  M2340989511     condo  2129000  ...          CA  Los Angeles           1916
# 196  M1573946266     condo   569000  ...          CA  Los Angeles            650
# 197  M2856613351     condo   749000  ...          CA  Los Angeles           1629
# 198  M1728220056     condo   465000  ...          CA  Los Angeles           1616
# 199  M2576741751     condo   499000  ...          CA  Los Angeles           1155
#
# ...

# %%
la_condo_df.drop(['address', 'building_size', 'state', 'fips_code', 'lat', 'lon', 'neighborhood_name', 'is_approximate', 'time_zone', 'units'], axis=1, inplace=True)
la_condo_df.rename(columns={'size': "building_size"}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b8c37b23262b> in <module>()
# ----> 1 la_condo_df.drop(['address', 'building_size', 'state', 'fips_code', 'lat', 'lon', 'neighborhood_name', 'is_approximate', 'time_zone', 'units'], axis=1, inplace=True)
#       2 la_condo_df.rename(columns={'size': "building_size"}, inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
la_condo_df
# Out:
#      property_id prop_type    price  ...  state_code       county  building_size
# 0    M1871614480     condo   475000  ...          CA  Los Angeles           1102
# 1    M1521023494     condo   525000  ...          CA  Los Angeles           1244
# 2    M2286048569     condo  1748000  ...          CA  Los Angeles           2628
# 3    M9715181242     condo   663990  ...          CA  Los Angeles           1918
# 4    M9295211483     condo   624990  ...          CA  Los Angeles           1786
# ..           ...       ...      ...  ...         ...          ...            ...
# 195  M2340989511     condo  2129000  ...          CA  Los Angeles           1916
# 196  M1573946266     condo   569000  ...          CA  Los Angeles            650
# 197  M2856613351     condo   749000  ...          CA  Los Angeles           1629
# 198  M1728220056     condo   465000  ...          CA  Los Angeles           1616
# 199  M2576741751     condo   499000  ...          CA  Los Angeles           1155
#
# ...

# %%
from google.colab import drive
drive.mount('/drive')
la_condo_df.to_csv('/drive/My Drive/UCI-IRV-2020-04/la_condo_listings.csv')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive
