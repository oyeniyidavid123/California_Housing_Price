# %%
import pandas as pd

from google.colab import drive
drive.mount('/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /drive

# %%
sd_condo = pd.read_csv("../drive/My Drive/UCI-IRV-2020-04/sandiego_condo_listings.csv")
anaheim_condo = pd.read_csv("../drive/My Drive/UCI-IRV-2020-04/anaheim_condo_listings.csv")
la_condo = pd.read_csv("../drive/My Drive/UCI-IRV-2020-04/la_condo_listings.csv")

# %%
merge1 = pd.concat([sd_condo, anaheim_condo])
merge2 = pd.concat([merge1, la_condo])

# %%
socal_condo = pd.DataFrame(merge2)

# %%
socal_condo.to_csv('/drive/My Drive/UCI-IRV-2020-04/socal_condo_listings.csv')
